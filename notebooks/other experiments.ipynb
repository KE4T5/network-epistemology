# %% [markdown]
# # Different features experiments

# %% [markdown]
# ## Setting initial credence

# %%
from numpy import random

# %% [markdown]
# Normal Distribution

# %%
random.normal(0, 1, 10)
# Out:
# array([ 1.20967379,  1.66663717, -0.43426   ,  0.33993739,  1.13083624,
#         1.30516869,  0.39889625, -0.92357562, -0.71553768,  0.61434466])

# %% [markdown]
# Uniform Distribution

# %%
random.uniform(0, 1, 10)
# Out:
# array([0.0942112 , 0.48384381, 0.06133185, 0.59050229, 0.09563738,
#        0.26184458, 0.3433689 , 0.10119225, 0.32521239, 0.56941837])

# %% [markdown]
# ## Doing experiment

# %% [markdown]
# ## Bayesian update
#
# Example:
# ![obraz.png](attachment:obraz.png)
#
# We can also see that on the basis of their
# credences in this particular network, four scientists will perform A
# (the light nodes) and two will perform B (the dark ones). Say they
# each perform their action ten times. In (b) we can see an example of
# results they might have obtained (2, 5, 7, etc.) Then in (c) we see
# how each scientist changes credences using Bayes’ rule on the basis
# of the outcomes observed by themselves and their neighbors. Anyone
# connected to someone who tried action B—the new, unknown
# treatment—will update their beliefs. (The scientist with credence
# .02 does not update since that scientist is not connected to anyone
# trying action B.) In this case all but one scientist increased their
# confidence in B, since, as expected, it tended to succeed more often
# than A. In fact, we can see that when they act next, five scientists
# will try B instead of A.

# %%
k = 12
n = 20
epsilon = 0.1
credence = 0.59
credence = 1 / (1 + 
                (1 - credence) * 
                (((0.5 - epsilon) / (0.5 + epsilon)) ** (2 * k - n)) / 
                credence
               )
print(credence)
# Out:
# 0.8793008279668814

# %%
1
# Out:
# 1

# %%
all(i == 0 for i in [0,0])
# Out:
# True
